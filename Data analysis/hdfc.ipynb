# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_excel('HDFC Bank.xlsx', sheet_name='Data Sheet', skiprows=55)

# %%
df.head(10)
# Out:
#                 Report Date 2014-03-31 00:00:00 2015-03-31 00:00:00  \
# 0      Equity Share Capital              479.81               501.3
# 1                  Reserves            43686.82            62652.77
# 2                Borrowings           416677.05            509761.9
# 3         Other Liabilities            42776.29            34180.55
# 4                     Total           503619.97           607096.52
# 5                 Net Block             3026.28             3224.94
# 6  Capital Work in Progress                 NaN                 NaN
# 7               Investments           119571.06           149454.42
# 8              Other Assets           381022.63           454417.16
# 9                     Total           503619.97           607096.52
#
#   2016-03-31 00:00:00 2017-03-31 00:00:00 2018-03-31 00:00:00  \
# 0              505.64              512.51              519.02
# 1            73798.49            91281.44           109080.11
# ...

# %%
Equity_Share = df.iloc[:,1]

# %%
Equity_Share
# Out:
# 0                  479.81
# 1                43686.82
# 2               416677.05
# 3                42776.29
# 4               503619.97
# 5                 3026.28
# 6                     NaN
# 7               119571.06
# 8               381022.63
# 9               503619.97
# 10                    NaN
# 11                    NaN
# 12               39913.43
# 13             2399050435
# 14                    NaN
# 15                      2
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19                    NaN
# 20                    NaN
# 21                    NaN
# 22                    NaN
# 23                    NaN
# 24    2014-03-31 00:00:00
# 25                4210.63
# 26               -1098.52
# 27                9270.15
# 28               12382.26
# 29                    NaN
# 30                    NaN
# 31                    NaN
# 32                    NaN
# 33                  374.4
# 34                    NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 plt.bar(Equity_Share)
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'bar'
